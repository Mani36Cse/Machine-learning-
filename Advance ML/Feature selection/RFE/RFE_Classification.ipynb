# %%
import pandas as pd
from RFE_classification import RFE_Classification
RC=RFE_Classification()

# %%
data_set=pd.read_csv("prep.csv")
#check the sample data
data_set.head(10)
# Out:
#    age         bp sg   al   su       rbc        pc         pcc          ba  \
# 0  2.0  76.459948  c  3.0  0.0    normal  abnormal  notpresent  notpresent
# 1  3.0  76.459948  c  2.0  0.0    normal    normal  notpresent  notpresent
# 2  4.0  76.459948  a  1.0  0.0    normal    normal  notpresent  notpresent
# 3  5.0  76.459948  d  1.0  0.0    normal    normal  notpresent  notpresent
# 4  5.0  50.000000  c  0.0  0.0    normal    normal  notpresent  notpresent
# 5  6.0  60.000000  c  4.0  0.0  abnormal  abnormal  notpresent     present
# 6  7.0  50.000000  a  4.0  0.0    normal    normal  notpresent  notpresent
# 7  8.0  60.000000  b  3.0  0.0    normal    normal  notpresent  notpresent
# 8  8.0  50.000000  a  4.0  0.0    normal    normal  notpresent  notpresent
# 9  8.0  76.459948  a  0.0  0.0    normal    normal  notpresent  notpresent
#
#           bgr  ...        pcv            wc        rc  htn  dm  cad  appet  \
# ...

# %%
#check rows and columns 
data_set.shape
# Out:
# (399, 25)

# %%
data_set.isna().sum()
#No null values found
# Out:
# age               0
# bp                0
# sg                0
# al                0
# su                0
# rbc               0
# pc                0
# pcc               0
# ba                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hrmo              0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
#data preprocessing
dataset=pd.get_dummies(data_set,drop_first=True)
dataset.head(5)
# Out:
#    age         bp   al   su         bgr         bu        sc         sod  \
# 0  2.0  76.459948  3.0  0.0  148.112676  57.482105  3.077356  137.528754
# 1  3.0  76.459948  2.0  0.0  148.112676  22.000000  0.700000  137.528754
# 2  4.0  76.459948  1.0  0.0   99.000000  23.000000  0.600000  138.000000
# 3  5.0  76.459948  1.0  0.0  148.112676  16.000000  0.700000  138.000000
# 4  5.0  50.000000  0.0  0.0  148.112676  25.000000  0.600000  137.528754
#
#         pot       hrmo  ...  pc_normal  pcc_present  ba_present  htn_yes  \
# 0  4.627244  12.518156  ...      False        False       False    False
# 1  4.627244  10.700000  ...       True        False       False    False
# 2  4.400000  12.000000  ...       True        False       False    False
# 3  3.200000   8.100000  ...       True        False       False    False
# 4  4.627244  11.800000  ...       True        False       False    False
#
#    dm_yes  cad_yes  appet_yes  pe_yes  ane_yes  classification_yes
# ...

# %%
#input and output split
inde_x=dataset.drop("classification_yes",axis=1)
depe_y=dataset["classification_yes"]

# %%
#Give input and output to RFE best algorithm, 5 no of cloumns accept 
value_x,column=RC.rfe_features(inde_x,depe_y,5)

# %%
print(column)
#These input columns are selected by the RFE
# Out:
# ['sc' 'pcv' 'sg_c' 'sg_d' 'pe_yes']

# %%
acclog=[]
accsvc=[]
accdes=[]
accrf=[]

# %%
#In value_x have more then one RFE result in list format, so give it loop get the result one by one.
#one model came and went to train and test, check in other models and give result
for i in value_x:
    x_train, x_test, y_train, y_test=RC.split_scaler(i,depe_y)
    
    classifier,Accuracy,report,x_test,y_test,cm=RC.Logistic(x_train,y_train,x_test,y_test)
    acclog.append(Accuracy)
    
    classifier,Accuracy,report,x_test,y_test,cm=RC.svc_linear(x_train,y_train,x_test,y_test)  
    accsvc.append(Accuracy)
    
    classifier,Accuracy,report,x_test,y_test,cm=RC.Decision(x_train,y_train,x_test,y_test)  
    accdes.append(Accuracy)
    
    classifier,Accuracy,report,x_test,y_test,cm=RC.random(x_train,y_train,x_test,y_test)  
    accrf.append(Accuracy)

# %%
#It store the 4 type of algorithms scores
accsvc
# Out:
# [0.975, 0.9833333333333333, 0.975, 0.975]

# %%
result=RC.rfe_classification(acclog,accsvc,accdes,accrf)

# %%
result
# Out:
#                 Linear       SVC DecisionTree    Random
# Linear           0.975     0.975        0.975     0.975
# SVC           0.983333  0.983333     0.983333  0.983333
# DecisionTree     0.975     0.975     0.941667  0.958333
# Random           0.975     0.975     0.966667  0.983333
