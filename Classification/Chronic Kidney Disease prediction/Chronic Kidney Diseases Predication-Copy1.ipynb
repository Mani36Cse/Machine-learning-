# %% [markdown]
# ### 1. Data collection

# %%
import pandas as pd

# %%
Data_set=pd.read_csv("CKD.csv")
Data_set
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# ...

# %%
Data=pd.get_dummies(Data_set,drop_first=True)
Data
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# ...

# %%
#above data we can't able to find all columns so we using this code to view all columns
sample=pd.set_option('display.max_columns',None)
print(Data.head())
# Out:
#    age         bp   al   su         bgr         bu        sc         sod  \
# 0  2.0  76.459948  3.0  0.0  148.112676  57.482105  3.077356  137.528754
# 1  3.0  76.459948  2.0  0.0  148.112676  22.000000  0.700000  137.528754
# 2  4.0  76.459948  1.0  0.0   99.000000  23.000000  0.600000  138.000000
# 3  5.0  76.459948  1.0  0.0  148.112676  16.000000  0.700000  138.000000
# 4  5.0  50.000000  0.0  0.0  148.112676  25.000000  0.600000  137.528754
#
#         pot       hrmo        pcv            wc        rc  sg_b  sg_c  sg_d  \
# 0  4.627244  12.518156  38.868902   8408.191126  4.705597     0     1     0
# 1  4.627244  10.700000  34.000000  12300.000000  4.705597     0     1     0
# 2  4.400000  12.000000  34.000000   8408.191126  4.705597     0     0     0
# 3  3.200000   8.100000  38.868902   8408.191126  4.705597     0     0     1
# 4  4.627244  11.800000  36.000000  12400.000000  4.705597     0     1     0
#
# ...

# %% [markdown]
# ### 2.Split the input and output

# %%
Independent=Data[["age","bp","al","su","bgr","bu","sc","sod","pot","hrmo","pcv","wc","rc","sg_b","sg_c","sg_d","sg_e","rbc_normal","pc_normal","pcc_present","ba_present","htn_yes","dm_yes","cad_yes","appet_yes","pe_yes","ane_yes"]]
Independent
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo        pcv            wc        rc  sg_b  \
# ...

# %%
Dependent=Data[["classification_yes"]]
Dependent
# Out:
#      classification_yes
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ..                  ...
# 394                   1
# 395                   1
# 396                   1
# 397                   1
# 398                   0
#
# [399 rows x 1 columns]

# %%
Data["classification_yes"].value_counts()
#Data set was imbalance data
# Out:
# 1    249
# 0    150
# Name: classification_yes, dtype: int64

# %% [markdown]
# ### 3.Split the train and test data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(Independent,Dependent, test_size=0.30, random_state=0)

# %%
x_test
# Out:
#       age     bp   al   su         bgr     bu    sc         sod       pot  \
# 132  46.0   70.0  0.0  0.0  100.000000   47.0   0.5  142.000000  3.500000
# 309  66.0   90.0  2.0  0.0  153.000000   76.0   3.3  137.528754  4.627244
# 334  69.0   70.0  0.0  0.0   83.000000   42.0   1.2  139.000000  3.700000
# 196  55.0  100.0  1.0  4.0  297.000000   53.0   2.8  139.000000  4.500000
# 246  60.0   90.0  2.0  0.0  105.000000   53.0   2.3  136.000000  5.200000
# ..    ...    ...  ...  ...         ...    ...   ...         ...       ...
# 216  57.0   90.0  5.0  0.0  148.112676  322.0  13.0  126.000000  4.800000
# 259  61.0   60.0  0.0  0.0  108.000000   75.0   1.9  141.000000  5.200000
# 49   30.0   60.0  0.0  0.0  120.000000   31.0   0.8  150.000000  4.600000
# 238  59.0   60.0  0.0  0.0  113.000000   23.0   1.1  139.000000  3.500000
# 342  70.0   60.0  0.0  0.0  120.000000   40.0   0.5  140.000000  4.600000
#
#           hrmo        pcv            wc        rc  sg_b  sg_c  sg_d  sg_e  \
# ...

# %% [markdown]
# from sklearn.preprocessing import StandardScaler
# sc=StandardScaler()
# x_train=sc.fit_transform(x_train)
# x_test=sc.transform(x_test)
# x_test

# %% [markdown]
# ### 4.Model crearion

# %%
#CategoricalNB

from sklearn.naive_bayes import CategoricalNB

from sklearn.model_selection import GridSearchCV

param_grid = {'alpha': [0.1, 1.0]}

grid=GridSearchCV(CategoricalNB(), param_grid, refit=True, verbose=3, n_jobs=-1, scoring='f1_weighted')

grid.fit(x_train,y_train)


y_pred=grid.predict(x_test)

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)

from sklearn.metrics import classification_report
cl=classification_report(y_test,y_pred)

from sklearn.metrics import roc_auc_score
roc_1=roc_auc_score(y_test,grid_1.predict_proba(x_test)[:,-1])

print("---> Naive Bayes - BernoulliNB  using Grid <---")
print()
print("Best value in Grid search :",grid_1.best_params_)
print()
print("Validaction values")
print(cm_1)
print()
print("Classifiaction reports")
print(cl_1)
print("roc and auc value :",roc_1)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# C:\Users\smani\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [nan nan]
#   warnings.warn(
# C:\Users\smani\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 14
#       9 grid=GridSearchCV(CategoricalNB(), param_grid, refit=True, verbose=3, n_jobs=-1, scoring='f1_weighted')
#      11 grid.fit(x_train,y_train)
# ---> 14 y_pred=grid.predict(x_test)
#      16 from sklearn.metrics import confusion_matrix
#      17 cm=confusion_matrix(y_test,y_pred)
#
# ...
