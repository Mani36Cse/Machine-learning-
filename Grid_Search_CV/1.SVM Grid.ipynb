# %%
import pandas as ps

# %% [markdown]
# ## 1.Data collection

# %%
Data=ps.read_csv("insurance_pre.csv")
Data
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#The data set have a categorical data so we are using Nominal menthod which is converting string to number
Data=ps.get_dummies(Data, drop_first=True)

# %%
Data
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
Data.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %% [markdown]
# ## 2.Input and Output Split

# %%
#Independent=Data[['R&D Spend', 'Administration', 'Marketing Spend', 'State_Florida', 'State_New York']]
Independent=Data[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
Independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
#Dependent=Data[['Profit']]
Dependent=Data[['charges']]
Dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %% [markdown]
# ## 3.Split the train and test data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(Independent, Dependent, test_size=0.30, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
#Here we are using Gird Search CV (cross validation) so no need to use train and test split, Gird will do that all the method.

# %% [markdown]
# ## 4. Model creation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

p_grid={'kernel':['linear','poly', 'rbf', 'sigmoid'], 'C':[10,100,500,1000],'gamma':['scale', 'auto'] }
#poly will take more time so if we run code without standard we can remove poly then code will runn fast.
#SVM mostly support standard data so better to work with standard data 

grid=GridSearchCV(SVR(),p_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(x_train, y_train)


##The data is split into 5 parts (folds), and the model is trained 5 times, each time using 4 folds for training and 1 fold for validation.
#50 models with different settings that are being tested. we have 3 parmeter so 5x4x2=40 
#5 rows and 40 columns = 200 fits
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# C:\Users\smani\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 500, 1000], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              verbose=3)

# %% [markdown]
# ## 5. Evalutation metric

# %%
#since we are using GridSearchCV so it will do Evalution the metric and give the best model

# %%
re=grid.cv_results_
# print the best parametar after tuning 
print("The Score value for the best model {}".format(grid.best_params_),"Score :",grid.best_score_)
# Out:
# The Score value for the best model {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'} Score : 0.7935546451669515

# %%
table=ps.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.035486      0.000444         0.007136        0.000238      10
# 1        0.034928      0.001228         0.007002        0.000002      10
# 2        0.037630      0.000802         0.017576        0.000790      10
# 3        0.040767      0.000635         0.009018        0.000922      10
# 4        0.033956      0.001473         0.006801        0.001027      10
# 5        0.032240      0.001492         0.007162        0.000946      10
# 6        0.037587      0.001397         0.017947        0.001005      10
# 7        0.041800      0.001498         0.009227        0.001016      10
# 8        0.041917      0.001015         0.006974        0.000832     100
# 9        0.036479      0.001395         0.008860        0.002084     100
# 10       0.039549      0.001721         0.017547        0.000407     100
# 11       0.043397      0.000330         0.008182        0.000990     100
# 12       0.040987      0.001024         0.005976        0.000112     100
# 13       0.036029      0.001773         0.008382        0.000691     100
# 14       0.038006      0.000681         0.017783        0.001271     100
# 15       0.042174      0.001046         0.008316        0.000730     100
# 16       0.042523      0.000983         0.007216        0.000981     500
# 17       0.044173      0.002704         0.007865        0.000125     500
# 18       0.045730      0.001503         0.017782        0.000002     500
# 19       0.044577      0.002653         0.009068        0.000857     500
# 20       0.043426      0.000127         0.006610        0.001048     500
# 21       0.044975      0.001446         0.006714        0.000968     500
# 22       0.044930      0.000797         0.017779        0.001268     500
# 23       0.045783      0.001904         0.009817        0.000101     500
# 24       0.047391      0.001739         0.006765        0.001030    1000
# 25       0.053258      0.011887         0.007865        0.000122    1000
# 26       0.047340      0.001268         0.017681        0.001193    1000
# 27       0.046584      0.001963         0.008720        0.000969    1000
# 28       0.046201      0.001515         0.006713        0.000857    1000
# 29       0.050903      0.007444         0.007116        0.000904    1000
# 30       0.046108      0.001007         0.014012        0.003133    1000
# 31       0.041670      0.002053         0.005989        0.001262    1000
#
#    param_gamma param_kernel  \
# 0        scale       linear
# 1        scale         poly
# 2        scale          rbf
# 3        scale      sigmoid
# 4         auto       linear
# 5         auto         poly
# 6         auto          rbf
# 7         auto      sigmoid
# 8        scale       linear
# 9        scale         poly
# 10       scale          rbf
# 11       scale      sigmoid
# 12        auto       linear
# 13        auto         poly
# 14        auto          rbf
# 15        auto      sigmoid
# 16       scale       linear
# 17       scale         poly
# 18       scale          rbf
# 19       scale      sigmoid
# 20        auto       linear
# 21        auto         poly
# 22        auto          rbf
# 23        auto      sigmoid
# 24       scale       linear
# 25       scale         poly
# 26       scale          rbf
# 27       scale      sigmoid
# 28        auto       linear
# 29        auto         poly
# 30        auto          rbf
# 31        auto      sigmoid
#
#                                                params  split0_test_score  \
# 0     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.377969
# 1       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.054964
# 2        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.004126
# 3    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.049644
# 4      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.377969
# 5        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.056274
# 6         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.004055
# 7     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.049905
# 8    {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.584474
# 9      {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.537117
# 10      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.301041
# 11  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.478930
# 12    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.584474
# 13      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.540643
# 14       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.300573
# 15   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.478364
# 16   {'C': 500, 'gamma': 'scale', 'kernel': 'linear'}           0.601152
# 17     {'C': 500, 'gamma': 'scale', 'kernel': 'poly'}           0.780516
# 18      {'C': 500, 'gamma': 'scale', 'kernel': 'rbf'}           0.601802
# 19  {'C': 500, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.466661
# 20    {'C': 500, 'gamma': 'auto', 'kernel': 'linear'}           0.601152
# 21      {'C': 500, 'gamma': 'auto', 'kernel': 'poly'}           0.781613
# 22       {'C': 500, 'gamma': 'auto', 'kernel': 'rbf'}           0.601529
# 23   {'C': 500, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.434785
# 24  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.605304
# 25    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.828213
# 26     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.733334
# 27  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.400044
# 28   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.605304
# 29     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.829631
# 30      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.733044
# 31  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.296082
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.479601           0.317872           0.337979
# 1            0.071297          -0.046513          -0.024157
# 2            0.013244          -0.103775          -0.095165
# 3            0.076323          -0.046798          -0.040824
# 4            0.479601           0.317872           0.337979
# 5            0.069532          -0.045601          -0.025079
# 6            0.013366          -0.103821          -0.095119
# 7            0.075905          -0.046585          -0.041004
# 8            0.655818           0.553380           0.576939
# 9            0.579373           0.471840           0.537966
# 10           0.338741           0.174086           0.217641
# 11           0.563200           0.427152           0.451250
# 12           0.655818           0.553380           0.576939
# 13           0.575051           0.474839           0.535730
# 14           0.339474           0.173708           0.217991
# 15           0.561673           0.428331           0.450454
# 16           0.599729           0.571527           0.542915
# 17           0.780878           0.753634           0.768982
# 18           0.640415           0.534267           0.570844
# 19           0.542011           0.413211           0.459869
# 20           0.599729           0.571527           0.542915
# 21           0.780025           0.754530           0.768597
# 22           0.640750           0.533952           0.571062
# 23           0.549481           0.435040           0.430290
# 24           0.588725           0.623230           0.537931
# 25           0.802622           0.799348           0.800587
# 26           0.745892           0.687037           0.717769
# 27           0.366097           0.242217           0.288461
# 28           0.588725           0.623230           0.537931
# 29           0.802622           0.799620           0.800321
# 30           0.746232           0.686773           0.717920
# 31           0.372281           0.216401           0.291265
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.324422         0.367569        0.059777               21
# 1           -0.049652         0.001188        0.051594               27
# 2           -0.101602        -0.056634        0.053486               32
# 3           -0.046521        -0.001635        0.053474               29
# 4            0.324422         0.367569        0.059777               21
# 5           -0.049592         0.001107        0.051309               28
# 6           -0.101604        -0.056625        0.053504               31
# 7           -0.046507        -0.001657        0.053391               30
# 8            0.546881         0.583498        0.038787                9
# 9            0.424478         0.510155        0.054955               16
# 10           0.183403         0.242982        0.065542               26
# 11           0.432199         0.470546        0.049762               17
# 12           0.546881         0.583498        0.038787                9
# 13           0.424640         0.510181        0.053582               15
# 14           0.183375         0.243024        0.065733               25
# 15           0.431701         0.470105        0.049110               18
# 16           0.565263         0.576117        0.022025               11
# 17           0.687296         0.754261        0.034926                4
# 18           0.521863         0.573838        0.043568               13
# 19           0.428703         0.462091        0.044535               19
# 20           0.565263         0.576117        0.022025               11
# 21           0.687317         0.754417        0.034925                3
# 22           0.521847         0.573828        0.043694               14
# 23           0.425720         0.455063        0.047332               20
# 24           0.616726         0.594383        0.030560                7
# 25           0.735555         0.793265        0.030757                2
# 26           0.649174         0.706641        0.034825                5
# 27           0.351407         0.329645        0.056742               23
# 28           0.616726         0.594383        0.030560                7
# 29           0.735580         0.793555        0.031072                1
# 30           0.649158         0.706625        0.034902                6
# 31           0.351325         0.305471        0.054387               24

# %%
age=int(input("Enter your age :"))
bmi=float(input("Enter your BMI : "))
children=int(input("Enter Children count:"))
Gen=int(input("Enter the gander if male enter 1, if female enter 0 :"))
smok=int(input("Enter if somker enter 1, if no somker enter 0 :"))
# Out:
# Enter your age :19
# Enter your BMI : 27.900
# Enter Children count:0
# Enter the gander if male enter 1, if female enter 0 :0
# Enter if somker enter 1, if no somker enter 0 :1

# %%
result=grid.predict([[age,bmi,children,Gen,smok]])

# %%
result
# Out:
# array([1513081.48057374])
