# %%
import pandas as ps

# %% [markdown]
# ## 1.Data collection

# %%
Data_set=ps.read_csv("insurance_pre.csv")

# %%
Data_set
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
Data_set=ps.get_dummies(Data_set,drop_first=True)
Data_set
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
Data_set.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %% [markdown]
# ## 2. Input & Output Split

# %%
Independent=Data_set[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
Independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
Dependent=Data_set[['charges']]
Dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %% [markdown]
# ## 3. Split the train and test data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(Independent, Dependent, test_size=0.30, random_state=0)

# %% [markdown]
# ## 4. Model creation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

p_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'], 'splitter':['best','random'],'max_features':['sqrt', 'log2'] }

grid=GridSearchCV(DecisionTreeRegressor(random_state=42),p_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(Independent, Dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %% [markdown]
# ## 5. Evalutation Metric

# %%
#since we are using GridSearchCV so it will do Evalution the metric and give the best model

# %%
re=grid.cv_results_
# print the best parametar after tuning 
print("The Score value for the best model {}".format(grid.best_params_),"Score :",grid.best_score_)
# Out:
# The Score value for the best model {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'} Score : 0.6975227781904909

# %%
table=ps.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.033855      0.011864         0.016976        0.005317
# 1        0.030918      0.015327         0.018482        0.010439
# 2        0.022435      0.006449         0.011922        0.003233
# 3        0.037864      0.014135         0.016178        0.004087
# 4        0.032707      0.014139         0.011071        0.004021
# 5        0.028340      0.004497         0.026439        0.012258
# 6        0.031602      0.006385         0.017393        0.006456
# 7        0.030772      0.007004         0.015831        0.006415
# 8        0.105204      0.009304         0.017776        0.007890
# 9        0.074921      0.012183         0.010214        0.002331
# 10       0.078184      0.008062         0.012483        0.002402
# 11       0.079652      0.012736         0.013124        0.002614
# 12       0.033957      0.010346         0.011818        0.004504
# 13       0.016777      0.002745         0.009215        0.001610
# 14       0.028345      0.011379         0.015274        0.005259
# 15       0.019277      0.002827         0.007913        0.005996
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.738749
# 1   {'criterion': 'squared_error', 'max_features':...           0.652415
# 2   {'criterion': 'squared_error', 'max_features':...           0.738749
# 3   {'criterion': 'squared_error', 'max_features':...           0.652415
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.739081
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.652415
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.739081
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.652415
# 8   {'criterion': 'absolute_error', 'max_features'...           0.714016
# 9   {'criterion': 'absolute_error', 'max_features'...           0.631721
# 10  {'criterion': 'absolute_error', 'max_features'...           0.714016
# 11  {'criterion': 'absolute_error', 'max_features'...           0.631721
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.775293
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.647831
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.775293
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.647831
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.640654           0.710509           0.679699
# 1            0.559122           0.686364           0.642094
# 2            0.640654           0.710509           0.679699
# 3            0.559122           0.686364           0.642094
# 4            0.640641           0.718205           0.679626
# 5            0.559122           0.686503           0.642059
# 6            0.640641           0.718205           0.679626
# 7            0.559122           0.686503           0.642059
# 8            0.542273           0.699056           0.714731
# 9            0.528585           0.621562           0.670972
# 10           0.542273           0.699056           0.714731
# 11           0.528585           0.621562           0.670972
# 12           0.696978           0.742946           0.632973
# 13           0.680533           0.721349           0.647465
# 14           0.696978           0.742946           0.632973
# 15           0.680533           0.721349           0.647465
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.710067         0.695936        0.033361                3
# 1            0.560956         0.620190        0.051255               15
# 2            0.710067         0.695936        0.033361                3
# 3            0.560956         0.620190        0.051255               15
# 4            0.710061         0.697523        0.034257                1
# 5            0.561569         0.620334        0.051146               13
# 6            0.710061         0.697523        0.034257                1
# 7            0.561569         0.620334        0.051146               13
# 8            0.769220         0.687859        0.076611                5
# 9            0.669209         0.624410        0.051805               11
# 10           0.769220         0.687859        0.076611                5
# 11           0.669209         0.624410        0.051805               11
# 12           0.550060         0.679650        0.080531                7
# 13           0.591434         0.657723        0.042815                9
# 14           0.550060         0.679650        0.080531                7
# 15           0.591434         0.657723        0.042815                9

# %%
age=int(input("Enter your age :"))
bmi=float(input("Enter your BMI : "))
children=int(input("Enter Children count:"))
Gen=int(input("Enter the gander if male enter 1, if female enter 0 :"))
smok=int(input("Enter if somker enter 1, if no somker enter 0 :"))
# Out:
# Enter your age :19
# Enter your BMI : 27.900
# Enter Children count:0
# Enter the gander if male enter 1, if female enter 0 :0
# Enter if somker enter 1, if no somker enter 0 :1

# %%
result=grid.predict([[age,bmi,children,Gen,smok]])
# Out:
# C:\Users\smani\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([16884.924])
